# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)


# Zip both lists and extract to a list of coordinates
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:

    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b2a691d9bfeae144a705c053319fcf96"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
     # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | staryy nadym
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | anadyr
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | vestmannaeyjar
# Processing Record 10 of Set 1 | esperance
# Processing Record 11 of Set 1 | sakete
# Processing Record 12 of Set 1 | changji
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | itarema
# Processing Record 15 of Set 1 | moose jaw
# Processing Record 16 of Set 1 | ulladulla
# Processing Record 17 of Set 1 | mount isa
# Processing Record 18 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | omaruru
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | stornoway
# Processing Record 28 of Set 1 | dzhebariki-khaya
# Processing Record 29 of Set 1 | ilebo
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | brae
# Processing Record 32 of Set 1 | tiarei
# Processing Record 33 of Set 1 | kenora
# Processing Record 34 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | buala
# Processing Record 41 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | teguise
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | camapua
# Processing Record 46 of Set 1 | raudeberg
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | denpasar
# Processing Record 50 of Set 1 | puri
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | monrovia
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | belmonte
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | khash
# Processing Record 10 of Set 2 | meulaboh
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | adrar
# Processing Record 13 of Set 2 | port-gentil
# Processing Record 14 of Set 2 | tabas
# Processing Record 15 of Set 2 | inhambane
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | udachnyy
# Processing Record 18 of Set 2 | zhigansk
# Processing Record 19 of Set 2 | te anau
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | kununurra
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | nouadhibou
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | spetsai
# City not found. Skipping...
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | leh
# Processing Record 28 of Set 2 | szczytno
# Processing Record 29 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | santiago de cao
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | impfondo
# Processing Record 36 of Set 2 | hasaki
# Processing Record 37 of Set 2 | raton
# Processing Record 38 of Set 2 | cairns
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 41 of Set 2 | zolotinka
# City not found. Skipping...
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | irbeyskoye
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | kaitangata
# Processing Record 49 of Set 2 | votice
# Processing Record 50 of Set 2 | dayong
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | bilibino
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | kualakapuas
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | provideniya
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | geraldton
# Processing Record 12 of Set 3 | jambusar
# Processing Record 13 of Set 3 | sinnamary
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | mayo
# Processing Record 17 of Set 3 | mporokoso
# Processing Record 18 of Set 3 | codajas
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | roros
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 3 | choucheng
# City not found. Skipping...
# Processing Record 25 of Set 3 | dewa
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 3 | san antonio del tachira
# Processing Record 29 of Set 3 | salalah
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | sao joao da barra
# Processing Record 32 of Set 3 | oktyabrskiy
# Processing Record 33 of Set 3 | bagdarin
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | barao de melgaco
# Processing Record 36 of Set 3 | quepos
# Processing Record 37 of Set 3 | port blair
# Processing Record 38 of Set 3 | moosomin
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | roald
# Processing Record 42 of Set 3 | erzin
# Processing Record 43 of Set 3 | los llanos de aridane
# Processing Record 44 of Set 3 | przasnysz
# Processing Record 45 of Set 3 | havelock
# Processing Record 46 of Set 3 | bathsheba
# Processing Record 47 of Set 3 | ahipara
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | biograd na moru
# Processing Record 50 of Set 3 | ulety
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | parauna
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | kupino
# Processing Record 7 of Set 4 | palmer
# Processing Record 8 of Set 4 | sri aman
# Processing Record 9 of Set 4 | severo-kurilsk
# Processing Record 10 of Set 4 | rocha
# Processing Record 11 of Set 4 | zafra
# Processing Record 12 of Set 4 | bengkulu
# Processing Record 13 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 4 | calvinia
# Processing Record 15 of Set 4 | tak
# Processing Record 16 of Set 4 | broome
# Processing Record 17 of Set 4 | waitara
# Processing Record 18 of Set 4 | newport
# Processing Record 19 of Set 4 | beloha
# Processing Record 20 of Set 4 | vammala
# Processing Record 21 of Set 4 | zwedru
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | san carlos de bariloche
# Processing Record 24 of Set 4 | paragominas
# Processing Record 25 of Set 4 | lagoa
# Processing Record 26 of Set 4 | sao gabriel da cachoeira
# Processing Record 27 of Set 4 | kamenka
# Processing Record 28 of Set 4 | kuandian
# Processing Record 29 of Set 4 | jardanhaza
# Processing Record 30 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | ayios kirikos
# City not found. Skipping...
# Processing Record 33 of Set 4 | yulara
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 4 | praia
# Processing Record 37 of Set 4 | saint george
# Processing Record 38 of Set 4 | yumen
# Processing Record 39 of Set 4 | saint-joseph
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | tecoanapa
# Processing Record 42 of Set 4 | antofagasta
# Processing Record 43 of Set 4 | labuhan
# Processing Record 44 of Set 4 | plouzane
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | san quintin
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | turukhansk
# Processing Record 49 of Set 4 | hofn
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | banjar
# Processing Record 3 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 5 | majene
# Processing Record 6 of Set 5 | jalpa
# Processing Record 7 of Set 5 | la union
# Processing Record 8 of Set 5 | caronport
# Processing Record 9 of Set 5 | nabire
# Processing Record 10 of Set 5 | burnie
# Processing Record 11 of Set 5 | alibag
# Processing Record 12 of Set 5 | ashtabula
# Processing Record 13 of Set 5 | porto novo
# Processing Record 14 of Set 5 | cayenne
# Processing Record 15 of Set 5 | katherine
# Processing Record 16 of Set 5 | qaanaaq
# Processing Record 17 of Set 5 | vardo
# Processing Record 18 of Set 5 | bethanien
# Processing Record 19 of Set 5 | faanui
# Processing Record 20 of Set 5 | zhanakorgan
# Processing Record 21 of Set 5 | teya
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | lavrentiya
# Processing Record 24 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 5 | saint-philippe
# Processing Record 26 of Set 5 | tautira
# Processing Record 27 of Set 5 | phan thiet
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | quelimane
# Processing Record 30 of Set 5 | safaga
# Processing Record 31 of Set 5 | nome
# Processing Record 32 of Set 5 | sur
# Processing Record 33 of Set 5 | malaryta
# Processing Record 34 of Set 5 | guarapari
# Processing Record 35 of Set 5 | garanhuns
# Processing Record 36 of Set 5 | gat
# Processing Record 37 of Set 5 | severo-yeniseyskiy
# Processing Record 38 of Set 5 | miram shah
# Processing Record 39 of Set 5 | mackay
# Processing Record 40 of Set 5 | newmarket
# Processing Record 41 of Set 5 | peleduy
# Processing Record 42 of Set 5 | thunder bay
# Processing Record 43 of Set 5 | hervey bay
# Processing Record 44 of Set 5 | naryan-mar
# Processing Record 45 of Set 5 | griffith
# Processing Record 46 of Set 5 | beira
# Processing Record 47 of Set 5 | ayios ioannis
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | vostok
# Processing Record 50 of Set 5 | bambanglipuro
# Processing Record 1 of Set 6 | kurumkan
# Processing Record 2 of Set 6 | bengkalis
# City not found. Skipping...
# Processing Record 3 of Set 6 | kavieng
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | iquique
# Processing Record 7 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | solone
# Processing Record 9 of Set 6 | katsuura
# Processing Record 10 of Set 6 | buchanan
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | pietarsaari
# Processing Record 13 of Set 6 | kawhia
# Processing Record 14 of Set 6 | puerto colombia
# Processing Record 15 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 6 | ancud
# Processing Record 17 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 6 | mayen
# Processing Record 19 of Set 6 | cuenca
# Processing Record 20 of Set 6 | zuwarah
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | fairbanks
# Processing Record 23 of Set 6 | storforshei
# Processing Record 24 of Set 6 | morros
# Processing Record 25 of Set 6 | chongqing
# Processing Record 26 of Set 6 | la ronge
# Processing Record 27 of Set 6 | santiago del estero
# Processing Record 28 of Set 6 | dzaoudzi
# Processing Record 29 of Set 6 | brantford
# Processing Record 30 of Set 6 | bima
# Processing Record 31 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 32 of Set 6 | tucuman
# Processing Record 33 of Set 6 | muros
# Processing Record 34 of Set 6 | sitka
# Processing Record 35 of Set 6 | coari
# Processing Record 36 of Set 6 | la macarena
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | abu dhabi
# Processing Record 39 of Set 6 | tasiilaq
# Processing Record 40 of Set 6 | krasnyy chikoy
# Processing Record 41 of Set 6 | mana
# Processing Record 42 of Set 6 | high level
# Processing Record 43 of Set 6 | ketchikan
# Processing Record 44 of Set 6 | bilma
# Processing Record 45 of Set 6 | ilhabela
# Processing Record 46 of Set 6 | shingu
# Processing Record 47 of Set 6 | sao filipe
# Processing Record 48 of Set 6 | tornio
# Processing Record 49 of Set 6 | manta
# Processing Record 50 of Set 6 | rio gallegos
# Processing Record 1 of Set 7 | nagod
# Processing Record 2 of Set 7 | gimbi
# Processing Record 3 of Set 7 | soe
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | katima mulilo
# Processing Record 6 of Set 7 | kizukuri
# Processing Record 7 of Set 7 | asau
# Processing Record 8 of Set 7 | turayf
# Processing Record 9 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | saskylakh
# Processing Record 11 of Set 7 | presidencia roque saenz pena
# Processing Record 12 of Set 7 | ribeira grande
# Processing Record 13 of Set 7 | maragogi
# Processing Record 14 of Set 7 | ihosy
# Processing Record 15 of Set 7 | tha bo
# Processing Record 16 of Set 7 | lundazi
# Processing Record 17 of Set 7 | keffi
# Processing Record 18 of Set 7 | barra patuca
# Processing Record 19 of Set 7 | rio grande
# Processing Record 20 of Set 7 | den helder
# Processing Record 21 of Set 7 | moyale
# Processing Record 22 of Set 7 | port hedland
# Processing Record 23 of Set 7 | orsha
# Processing Record 24 of Set 7 | faya
# Processing Record 25 of Set 7 | amahai
# Processing Record 26 of Set 7 | ipira
# Processing Record 27 of Set 7 | kawalu
# Processing Record 28 of Set 7 | labrea
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | kattivakkam
# Processing Record 31 of Set 7 | praya
# Processing Record 32 of Set 7 | bealanana
# Processing Record 33 of Set 7 | bonthe
# Processing Record 34 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 35 of Set 7 | shizunai
# Processing Record 36 of Set 7 | dennery
# Processing Record 37 of Set 7 | lebu
# Processing Record 38 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 7 | kalmunai
# Processing Record 40 of Set 7 | isugod
# Processing Record 41 of Set 7 | rosetta
# Processing Record 42 of Set 7 | lasa
# Processing Record 43 of Set 7 | namatanai
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | lima
# Processing Record 46 of Set 7 | guerrero
# Processing Record 47 of Set 7 | san cristobal
# Processing Record 48 of Set 7 | mikhaylovskoye
# Processing Record 49 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 7 | katobu
# Processing Record 1 of Set 8 | belyy yar
# Processing Record 2 of Set 8 | porto murtinho
# Processing Record 3 of Set 8 | urucui
# Processing Record 4 of Set 8 | chistogorskiy
# Processing Record 5 of Set 8 | kushmurun
# Processing Record 6 of Set 8 | flinders
# Processing Record 7 of Set 8 | morgan city
# Processing Record 8 of Set 8 | hambantota
# Processing Record 9 of Set 8 | omboue
# Processing Record 10 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 8 | mbandaka
# Processing Record 12 of Set 8 | grindavik
# Processing Record 13 of Set 8 | rincon
# Processing Record 14 of Set 8 | kaniama
# Processing Record 15 of Set 8 | zhezkazgan
# Processing Record 16 of Set 8 | homburg
# Processing Record 17 of Set 8 | manokwari
# Processing Record 18 of Set 8 | ranong
# Processing Record 19 of Set 8 | sokoto
# Processing Record 20 of Set 8 | cooma
# Processing Record 21 of Set 8 | williston
# Processing Record 22 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 23 of Set 8 | la rioja
# Processing Record 24 of Set 8 | basco
# Processing Record 25 of Set 8 | kibre mengist
# Processing Record 26 of Set 8 | dharchula
# Processing Record 27 of Set 8 | nhulunbuy
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | kure
# Processing Record 30 of Set 8 | port moresby
# Processing Record 31 of Set 8 | agua verde
# Processing Record 32 of Set 8 | preobrazheniye
# Processing Record 33 of Set 8 | datong
# Processing Record 34 of Set 8 | almaznyy
# Processing Record 35 of Set 8 | manacapuru
# Processing Record 36 of Set 8 | portland
# Processing Record 37 of Set 8 | nur
# Processing Record 38 of Set 8 | kurilsk
# Processing Record 39 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 8 | constanta
# Processing Record 41 of Set 8 | surt
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | lengshuijiang
# Processing Record 44 of Set 8 | elizabeth city
# Processing Record 45 of Set 8 | lieto
# Processing Record 46 of Set 8 | natal
# Processing Record 47 of Set 8 | gillette
# Processing Record 48 of Set 8 | neepawa
# Processing Record 49 of Set 8 | chikwawa
# Processing Record 50 of Set 8 | lata
# Processing Record 1 of Set 9 | coquimbo
# Processing Record 2 of Set 9 | simao
# Processing Record 3 of Set 9 | del rio
# Processing Record 4 of Set 9 | bubaque
# Processing Record 5 of Set 9 | saint simons
# Processing Record 6 of Set 9 | ust-nera
# Processing Record 7 of Set 9 | cukai
# Processing Record 8 of Set 9 | komsomolskiy
# Processing Record 9 of Set 9 | port dover
# Processing Record 10 of Set 9 | leningradskiy
# Processing Record 11 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 9 | marawi
# Processing Record 13 of Set 9 | gombong
# Processing Record 14 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 9 | santa cruz
# Processing Record 16 of Set 9 | fare
# Processing Record 17 of Set 9 | cururupu
# Processing Record 18 of Set 9 | carballo
# Processing Record 19 of Set 9 | gizo
# Processing Record 20 of Set 9 | mogadishu
# Processing Record 21 of Set 9 | saint-pierre
# Processing Record 22 of Set 9 | longyearbyen
# Processing Record 23 of Set 9 | general roca
# Processing Record 24 of Set 9 | mount gambier
# Processing Record 25 of Set 9 | pokhara
# Processing Record 26 of Set 9 | port alberni
# Processing Record 27 of Set 9 | puerto madero
# Processing Record 28 of Set 9 | carutapera
# Processing Record 29 of Set 9 | hovd
# Processing Record 30 of Set 9 | viedma
# Processing Record 31 of Set 9 | tilichiki
# Processing Record 32 of Set 9 | kikwit
# Processing Record 33 of Set 9 | algiers
# Processing Record 34 of Set 9 | bulgan
# Processing Record 35 of Set 9 | la orilla
# Processing Record 36 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 9 | berea
# Processing Record 38 of Set 9 | xiongyue
# Processing Record 39 of Set 9 | rawlins
# Processing Record 40 of Set 9 | gagino
# Processing Record 41 of Set 9 | constitucion
# Processing Record 42 of Set 9 | moron
# Processing Record 43 of Set 9 | harper
# Processing Record 44 of Set 9 | deputatskiy
# Processing Record 45 of Set 9 | haines junction
# Processing Record 46 of Set 9 | sandwick
# Processing Record 47 of Set 9 | siocon
# Processing Record 48 of Set 9 | namibe
# Processing Record 49 of Set 9 | sabha
# Processing Record 50 of Set 9 | dzitbalche
# Processing Record 1 of Set 10 | havre-saint-pierre
# Processing Record 2 of Set 10 | sidi ali
# Processing Record 3 of Set 10 | suleja
# Processing Record 4 of Set 10 | tyukalinsk
# Processing Record 5 of Set 10 | huarmey
# Processing Record 6 of Set 10 | ballina
# Processing Record 7 of Set 10 | santa lucia
# Processing Record 8 of Set 10 | kapan
# Processing Record 9 of Set 10 | sorland
# Processing Record 10 of Set 10 | burica
# City not found. Skipping...
# Processing Record 11 of Set 10 | goderich
# Processing Record 12 of Set 10 | karratha
# Processing Record 13 of Set 10 | ewa beach
# Processing Record 14 of Set 10 | saint-augustin
# Processing Record 15 of Set 10 | prabumulih
# Processing Record 16 of Set 10 | birjand
# Processing Record 17 of Set 10 | sao sebastiao
# Processing Record 18 of Set 10 | hermitage
# Processing Record 19 of Set 10 | hesla
# Processing Record 20 of Set 10 | rudbar
# Processing Record 21 of Set 10 | abonnema
# Processing Record 22 of Set 10 | tombouctou
# Processing Record 23 of Set 10 | ruteng
# Processing Record 24 of Set 10 | biak
# Processing Record 25 of Set 10 | pandan niog
# Processing Record 26 of Set 10 | champasak
# Processing Record 27 of Set 10 | balta
# Processing Record 28 of Set 10 | russell
# Processing Record 29 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 30 of Set 10 | olafsvik
# Processing Record 31 of Set 10 | bandarbeyla
# Processing Record 32 of Set 10 | tahe
# Processing Record 33 of Set 10 | barinas
# Processing Record 34 of Set 10 | aljezur
# Processing Record 35 of Set 10 | skibbereen
# Processing Record 36 of Set 10 | nizhniy kuranakh
# Processing Record 37 of Set 10 | seoul
# Processing Record 38 of Set 10 | capim grosso
# Processing Record 39 of Set 10 | winchester
# Processing Record 40 of Set 10 | ponta delgada
# Processing Record 41 of Set 10 | humberto de campos
# Processing Record 42 of Set 10 | ambilobe
# Processing Record 43 of Set 10 | riviere-au-renard
# Processing Record 44 of Set 10 | hualmay
# Processing Record 45 of Set 10 | fougamou
# Processing Record 46 of Set 10 | laguna
# Processing Record 47 of Set 10 | dwarka
# Processing Record 48 of Set 10 | kirakira
# Processing Record 49 of Set 10 | atambua
# Processing Record 50 of Set 10 | kentau
# Processing Record 1 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 11 | tommot
# Processing Record 3 of Set 11 | sao miguel do araguaia
# Processing Record 4 of Set 11 | nuuk
# Processing Record 5 of Set 11 | kovilj
# Processing Record 6 of Set 11 | baykit
# Processing Record 7 of Set 11 | caetite
# Processing Record 8 of Set 11 | lumut
# Processing Record 9 of Set 11 | agadez
# Processing Record 10 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 11 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 12 of Set 11 | chute-aux-outardes
# Processing Record 13 of Set 11 | tambopata
# Processing Record 14 of Set 11 | celestun
# Processing Record 15 of Set 11 | chulman
# Processing Record 16 of Set 11 | cabedelo
# Processing Record 17 of Set 11 | dunedin
# Processing Record 18 of Set 11 | qibili
# City not found. Skipping...
# Processing Record 19 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 11 | atasu
# Processing Record 21 of Set 11 | saldanha
# Processing Record 22 of Set 11 | dhidhdhoo
# Processing Record 23 of Set 11 | svetlyy
# Processing Record 24 of Set 11 | emba
# Processing Record 25 of Set 11 | ostrovnoy
# Processing Record 26 of Set 11 | koslan
# Processing Record 27 of Set 11 | shanghai
# Processing Record 28 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | tres arroyos
# Processing Record 30 of Set 11 | bereda
# Processing Record 31 of Set 11 | mount vernon
# Processing Record 32 of Set 11 | strezhevoy
# Processing Record 33 of Set 11 | mabaruma
# Processing Record 34 of Set 11 | tateyama
# Processing Record 35 of Set 11 | voyvozh
# Processing Record 36 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 11 | kimbe
# Processing Record 38 of Set 11 | pacifica
# Processing Record 39 of Set 11 | mecca
# Processing Record 40 of Set 11 | we
# City not found. Skipping...
# Processing Record 41 of Set 11 | solnechnyy
# Processing Record 42 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 11 | samarai
# Processing Record 44 of Set 11 | vorotynets
# Processing Record 45 of Set 11 | winnemucca
# Processing Record 46 of Set 11 | menongue
# Processing Record 47 of Set 11 | kloulklubed
# Processing Record 48 of Set 11 | nara
# Processing Record 49 of Set 11 | ciudad guayana
# Processing Record 50 of Set 11 | simbahan
# Processing Record 1 of Set 12 | pacific grove
# Processing Record 2 of Set 12 | along
# Processing Record 3 of Set 12 | kavaratti
# Processing Record 4 of Set 12 | bushehr
# Processing Record 5 of Set 12 | narsaq
# Processing Record 6 of Set 12 | aswan
# Processing Record 7 of Set 12 | alofi
# Processing Record 8 of Set 12 | tessalit
# Processing Record 9 of Set 12 | galle
# Processing Record 10 of Set 12 | muli
# Processing Record 11 of Set 12 | touros
# Processing Record 12 of Set 12 | kargopol
# Processing Record 13 of Set 12 | vila franca do campo
# Processing Record 14 of Set 12 | vila velha
# Processing Record 15 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 12 | kuusamo
# Processing Record 17 of Set 12 | grand gaube
# Processing Record 18 of Set 12 | tacuarembo
# Processing Record 19 of Set 12 | nortelandia
# Processing Record 20 of Set 12 | porbandar
# Processing Record 21 of Set 12 | ambulu
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | pasinler
# Processing Record 24 of Set 12 | taoudenni
# Processing Record 25 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 26 of Set 12 | ugoofaaru
# Processing Record 27 of Set 12 | miri
# Processing Record 28 of Set 12 | nieuw amsterdam
# Processing Record 29 of Set 12 | port augusta
# Processing Record 30 of Set 12 | sarai alamgir
# Processing Record 31 of Set 12 | lifford
# Processing Record 32 of Set 12 | gigante
# Processing Record 33 of Set 12 | sioux lookout
# Processing Record 34 of Set 12 | chapais
# Processing Record 35 of Set 12 | moree
# Processing Record 36 of Set 12 | tabriz
# Processing Record 37 of Set 12 | mmabatho
# Processing Record 38 of Set 12 | key west
# Processing Record 39 of Set 12 | kneza
# City not found. Skipping...
# Processing Record 40 of Set 12 | warrington
# Processing Record 41 of Set 12 | boa vista
# Processing Record 42 of Set 12 | borgarnes
# Processing Record 43 of Set 12 | ekhabi
# Processing Record 44 of Set 12 | codrington
# Processing Record 45 of Set 12 | naze
# Processing Record 46 of Set 12 | asyut
# Processing Record 47 of Set 12 | goundam
# Processing Record 48 of Set 12 | imbituba
# Processing Record 49 of Set 12 | waingapu
# Processing Record 50 of Set 12 | namie
# Processing Record 1 of Set 13 | nishihara
# Processing Record 2 of Set 13 | daru
# Processing Record 3 of Set 13 | husavik
# Processing Record 4 of Set 13 | port macquarie
# Processing Record 5 of Set 13 | manjacaze
# Processing Record 6 of Set 13 | moses lake
# Processing Record 7 of Set 13 | huinan
# Processing Record 8 of Set 13 | barcelos
# Processing Record 9 of Set 13 | berbera
# Processing Record 10 of Set 13 | kenscoff
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 555

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Staryy Nadym  65.6118   72.6842    -24.32        99          10
# 1          Lompoc  34.6391 -120.4579     55.85       100         100
# 2         Kahului  20.8947 -156.4700     66.22        82           0
# 3   Mar Del Plata -38.0023  -57.5575     73.94        63           0
# 4          Anadyr  64.7500  177.4833    -16.10        69           0
# 5     Tuktoyaktuk  69.4541 -133.0374     -3.19        97          96
# 6     Port Alfred -33.5906   26.8910     73.18        58          40
# 7  Vestmannaeyjar  63.4427  -20.2734     18.59        62           0
# 8       Esperance -33.8667  121.9000     73.49        57           0
# 9          Sakete   6.7362    2.6587     93.81        14          19
#
#    Wind Speed Country Current Description
# 0        5.08      HT           clear sky
# 1        5.75      HT     overcast clouds
# 2        3.44      HT           clear sky
# 3       18.41      HT           clear sky
# 4       13.42      HT           clear sky
# 5        7.43      HT     overcast clouds
# 6        1.99      HT    scattered clouds
# 7       20.71      HT           clear sky
# 8       21.54      HT           clear sky
# 9        5.88      HT          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = pd.DataFrame(city_data)[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Staryy Nadym      HT  65.6118   72.6842    -24.32        99          10
# 1          Lompoc      HT  34.6391 -120.4579     55.85       100         100
# 2         Kahului      HT  20.8947 -156.4700     66.22        82           0
# 3   Mar Del Plata      HT -38.0023  -57.5575     73.94        63           0
# 4          Anadyr      HT  64.7500  177.4833    -16.10        69           0
# 5     Tuktoyaktuk      HT  69.4541 -133.0374     -3.19        97          96
# 6     Port Alfred      HT -33.5906   26.8910     73.18        58          40
# 7  Vestmannaeyjar      HT  63.4427  -20.2734     18.59        62           0
# 8       Esperance      HT -33.8667  121.9000     73.49        57           0
# 9          Sakete      HT   6.7362    2.6587     93.81        14          19
#
#    Wind Speed Current Description
# 0        5.08           clear sky
# 1        5.75     overcast clouds
# 2        3.44           clear sky
# 3       18.41           clear sky
# 4       13.42           clear sky
# 5        7.43     overcast clouds
# 6        1.99    scattered clouds
# 7       20.71           clear sky
# 8       21.54           clear sky
# 9        5.88          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
